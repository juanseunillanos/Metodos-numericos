# %% [markdown]
# # 9.9
# Use la eliminación de Gauss para resolver el sistema que sigue:
#
# 8x1 + 2x2 – 2x3 = –2
#
# 10x1 + 2x2 + 4x3 = 4
#
# 12x1 + 2x2 + 2x3 = 6

# %%
m,b,x,n,det,factor,tol,s,er = [],[],[],3,1.0,0.0,0.0,[],0.0
    
m=[[8.0,2.0,-2.0],[10.0,2.0,4.0],[12.0,2.0,2.0]] 
b=[-2.0,4.0,6.0]
x=[0.0,0.0,0.0]
s=[0.0,0.0,0.0]
        
def eliminate(m,s,n,b,tol,er):
    for k in range(0,n):
        pivot(m,b,s,n,k)
        if (abs(m[k][k]/s[k])<tol):
            er=-1
        for i in range(k+1,n):
            factor = m[i][k]/m[k][k]
            for j in range (k+1,n):
                m[i][j]=m[i][j]-factor*m[k][j]
            b[i]=b[i]-factor*b[k]
    
    if (abs(m[k][k]/s[k])<tol):
        er=-1
        
def pivot(m,b,s,n,k):
    p,k=0,0
    p=k
    big = abs(m[k][k]/s[k])
    for i in range(k+1,n):
        dummy = abs(m[i][k]/s[i])
        if (dummy>big):
            big=dummy
            p=i
    if (p!=k):
        for j in range(k,n):
            dummy=m[p][j]
            m[p][j]=m[k][j]
            m[k][j]=dummy
        dummy=b[p]
        b[p]=b[k]
        b[k]=dummy
        dummy=s[p]
        s[p]=s[k]
        s[k]=dummy
    
def substitute(m,n,b,x):
    x[n-1]=b[n-1]/m[n-1][n-1]
    i=n-1
    while (i>=0):
        suma = 0
        for j in range(i+1,n):
            suma=suma+x[j]*m[i][j]
        x[i]=(b[i]-suma)/m[i][i]
        i -= 1
    for i in range(0,n):
        k=i+1
        print ("")
        print ("El valor de la incognita X%d es %f"%(k,x[i]))
    
def gauss(m,b,n,x,tol,er):
    for i in range(0,n):
        s[i]=abs(m[i][1])
        for j in range(1,n):
            if (abs(m[i][j])>s[i]):
                s[i]=abs(m[i][j])
    eliminate(m,s,n,b,tol,er)
    if (er!=-1):
        substitute(m,n,b,x)


def verificar():

    x1,x2,x3 = x[0],x[1],x[2]
    fun = round(8*x1 + 2*x2 - 2*x3)
    fun2 = round(10*x1 + 2*x2 + 4*x3)
    fun3 = round(12*x1 + 2*x2 + 2*x3)
    if (fun==-2 and fun2==4 and fun3==6):
        print ("")
        print ("El valor de las x es correcto")
        
gauss(m,b,n,x,tol,er)
verificar()
# Out:
# El valor de la incognita X1 es 1.500000
#
# El valor de la incognita X2 es -6.500000
#
# El valor de la incognita X3 es 0.500000
#
# El valor de las x es correcto

# %% [markdown]
# # 9.10
# 9.10 Dado el sistema siguiente de ecuaciones
#
# –3x2 + 7x3 = 2
#
# x1 + 2x2 – x3 = 3
#
# 5x1 – 2x2 = 2
#
# a) Calcule el determinante.
#
# b) Use la regla de Cramer para encontrar cuáles son los valores
# de las x.
#
# c) Emplee la eliminación de Gauss con pivoteo parcial para
# obtener cuáles serían los valores de las x.
#
# d) Sustituya sus resultados en las ecuaciones originales para
# efectos de comprobación.

# %%
#A y B
import math
matriz=[[0,-3,7],[1,2,-1],[5,-2,0]]
det=0
    
a=[2,3,2] 
    
print ("la determinante es")
det=matriz[0][0]*((matriz[1][1])*matriz[2][2]-(matriz[2][1])*matriz[1][2])-matriz[0][1]*((matriz[1][0])*matriz[2][2]-(matriz[2][0])*matriz[1][2])+matriz[0][2]*((matriz[1][0])*matriz[2][1]-(matriz[2][0])*matriz[1][1])
print ("%f"%(det))
    

    
def solucion(a,b,c):
  j=0   
  while (j<3):
    if(j==0): 
        detr=a*((matriz[1][1])*matriz[2][2]-(matriz[2][1])*matriz[1][2])-b*((matriz[0][1])*matriz[2][2]-(matriz[2][1])*matriz[0][2])+c*((matriz[0][1])*matriz[1][2]-(matriz[0][2])*matriz[1][1])
        print ("X1 = %f" %(detr/det))
    if(j==1): 
        detr2=a*((matriz[1][0])*matriz[2][2]-(matriz[2][0])*matriz[1][2])-b*((matriz[0][0])*matriz[2][2]-(matriz[2][0])*matriz[0][2])+c*((matriz[0][0])*matriz[1][2]-(matriz[0][2])*matriz[1][0])
        print ("X2 = %f" %(detr2/det))
    if(j==2): 
        detr3=a*((matriz[1][0])*matriz[2][1]-(matriz[2][0])*matriz[1][1])-b*((matriz[0][0])*matriz[2][1]-(matriz[2][0])*matriz[0][1])+c*((matriz[0][0])*matriz[1][1]-(matriz[0][1])*matriz[1][0])
        print ("X3 = %f" %(detr3/det))
    j=j+1        
        
print ("el valor de las x es:")
solucion(a[0],a[1],a[2])
# Out:
# la determinante es
# -69.000000
# el valor de las x es:
# X1 = 0.985507
# X2 = -1.463768
# X3 = 0.913043

# %%
#C y D
m,b,x,n,det,factor,tol,s,er = [],[],[],3,1.0,0.0,0.0,[],0.0
m=[[0.0,-3.0,7.0],[1.0,2.0,-1.0],[5.0,-2.0,0.0]] 
b=[2.0,3.0,2.0]
x=[0.0,0.0,0.0]
s=[0.0,0.0,0.0]
        
def eliminate(m,s,n,b,tol,er):
    for k in range(0,n):
        pivot(m,b,s,n,k)
        if (abs(m[k][k]/s[k])<tol):
            er=-1
        for i in range(k+1,n):
            factor = m[i][k]/m[k][k]
            for j in range (k+1,n):
                m[i][j]=m[i][j]-factor*m[k][j]
            b[i]=b[i]-factor*b[k]
    
    if (abs(m[k][k]/s[k])<tol):
        er=-1
        
def pivot(m,b,s,n,k):
    p,k=0,0
    p=k
    big = abs(m[k][k]/s[k])
    for i in range(k+1,n):
        dummy = abs(m[i][k]/s[i])
        if (dummy>big):
            big=dummy
            p=i
    if (p!=k):
        for j in range(k,n):
            dummy=m[p][j]
            m[p][j]=m[k][j]
            m[k][j]=dummy
        dummy=b[p]
        b[p]=b[k]
        b[k]=dummy
        dummy=s[p]
        s[p]=s[k]
        s[k]=dummy
    
def substitute(m,n,b,x):
    x[n-1]=b[n-1]/m[n-1][n-1]
    i=n-1
    while (i>=0):
        suma = 0
        for j in range(i+1,n):
            suma=suma+x[j]*m[i][j]
        x[i]=(b[i]-suma)/m[i][i]
        i -= 1
    for i in range(0,n):
        k=i+1
        print ("")
        print ("El valor de la incognita X%d es %f"%(k,x[i]))
    
def gauss(m,b,n,x,tol,er):
    for i in range(0,n):
        s[i]=abs(m[i][1])
        for j in range(1,n):
            if (abs(m[i][j])>s[i]):
                s[i]=abs(m[i][j])
    eliminate(m,s,n,b,tol,er)
    if (er!=-1):
        substitute(m,n,b,x)

def verificar():

    x1,x2,x3 = x[0],x[1],x[2]
    fun = round(-3*x2 + 7*x3)
    fun2 = round(x1 + 2*x2 - x3)
    fun3 = round(5*x1 - 2*x2)
    if (fun==2 and fun2==3 and fun3==2):
        print ("")
        print ("El valor de las x es correcto")
        
gauss(m,b,n,x,tol,er)
verificar()
# Out:
# El valor de la incognita X1 es 0.985507
#
# El valor de la incognita X2 es 1.463768
#
# El valor de la incognita X3 es 0.913043
#
# El valor de las x es correcto

# %% [markdown]
# # 9.11
# Dadas las ecuaciones:
#
# 2x1 – 6x2 – x3 = –38
#
# –3x1 – x2 + 7x3 = –34
#
# –8x1 + x2 – 2x3 = –20
#
# a) Resuelva por eliminación de Gauss con pivoteo parcial.
# Efectúe todos los pasos del cálculo.
#
# b) Sustituya los resultados en las ecuaciones originales para
# comprobar sus respuestas.

# %%
m,b,x,n,det,factor,tol,s,er = [],[],[],3,1.0,0.0,0.0,[],0.0    
m=[[2.0,-6.0,-1.0],[-3.0,-1.0,7.0],[-8.0,1.0,-2.0]] 
b=[-38.0,-34.0,-20.0]
x=[0.0,0.0,0.0]
s=[0.0,0.0,0.0]
        
def eliminate(m,s,n,b,tol,er):
    for k in range(0,n):
        pivot(m,b,s,n,k)
        if (abs(m[k][k]/s[k])<tol):
            er=-1
        for i in range(k+1,n):
            factor = m[i][k]/m[k][k]
            for j in range (k+1,n):
                m[i][j]=m[i][j]-factor*m[k][j]
            b[i]=b[i]-factor*b[k]
    
    if (abs(m[k][k]/s[k])<tol):
        er=-1
        
def pivot(m,b,s,n,k):
    p,k=0,0
    p=k
    big = abs(m[k][k]/s[k])
    for i in range(k+1,n):
        dummy = abs(m[i][k]/s[i])
        if (dummy>big):
            big=dummy
            p=i
    if (p!=k):
        for j in range(k,n):
            dummy=m[p][j]
            m[p][j]=m[k][j]
            m[k][j]=dummy
        dummy=b[p]
        b[p]=b[k]
        b[k]=dummy
        dummy=s[p]
        s[p]=s[k]
        s[k]=dummy
    
def substitute(m,n,b,x):
    x[n-1]=b[n-1]/m[n-1][n-1]
    i=n-1
    while (i>=0):
        suma = 0
        for j in range(i+1,n):
            suma=suma+x[j]*m[i][j]
        x[i]=(b[i]-suma)/m[i][i]
        i -= 1
    for i in range(0,n):
        k=i+1
        print ("")
        print ("El valor de la incognita X%d es %f"%(k,x[i]))
    
def gauss(m,b,n,x,tol,er):
    for i in range(0,n):
        s[i]=abs(m[i][1])
        for j in range(1,n):
            if (abs(m[i][j])>s[i]):
                s[i]=abs(m[i][j])
    eliminate(m,s,n,b,tol,er)
    if (er!=-1):
        substitute(m,n,b,x)

def verificar():

    x1,x2,x3 = x[0],x[1],x[2]
    fun = round(2*x1 - 6*x2 - x3)
    fun2 = round(-3*x1 - x2 + 7*x3)
    fun3 = round(-8*x1 + x2 - 2*x3)
    if (fun==-38 and fun2==-34 and fun3==-20):
        print ("")
        print ("El valor de las x es correcto")
        
gauss(m,b,n,x,tol,er)
verificar()
# Out:
# El valor de la incognita X1 es 4.000000
#
# El valor de la incognita X2 es 8.000000
#
# El valor de la incognita X3 es -2.000000
#
# El valor de las x es correcto

# %% [markdown]
# # 9.12
# Emplee la eliminación de Gauss-Jordan para resolver el
# sistema siguiente:
#
# 2x1 + x2 – x3 = 1
#
# 5x1 + 2x2 + 2x3 = –4
#
# 3x1 + x2 + x3 = 5
#
# No utilice pivoteo. Compruebe sus respuestas con la sustitución
# en las ecuaciones originales.

# %%
v,cte,m = 3,0,[]
m=[[2.0,1,-1,1],[5,2,2,-4],[3,1,1,5]]

def div(m,cte,v):
    temp=0.0
    temp=m[cte][cte]
    for y in range(0,v+1):
        m[cte][y]=m[cte][y]/temp
        
def Ceros(m,cte,v):
    for x in range(0,v):
        if (x!=cte):
            c = m[x][cte]
            for z in range(0,v+1):
                m[x][z]=((-1*c)*m[cte][z])+m[x][z]
                
for a in range(0,v):
    div(m,cte,v)
    Ceros(m,cte,v)
    cte += 1
for x in range(0,v):
    print ("La variable X%d es: %f"%(x+1,m[x][v]))
    
def verificar():

    x1,x2,x3 = m[0][3],m[1][3],m[2][3]
    fun = round(2*x1 + x2 - x3)
    fun2 = round(5*x1 + 2*x2 + 2*x3)
    fun3 = round(3*x1 + x2 + x3)

    if (fun==1 and fun2==-4 and fun3==5):
        print ("")
        print ("El valor de las x es correcto")
        
verificar()
# Out:
# La variable X1 es: 14.000000
# La variable X2 es: -32.000000
# La variable X3 es: -5.000000
#
# El valor de las x es correcto

# %% [markdown]
# # 9.13
# Resuelva el sistema:
#
# x1 + x2 – x3 = –3
#
# 6x1 + 2x2 + 2x3 = 2
#
# –3x1 + 4x2 + x3 = 1
#
# por medio de:
#
# a) eliminación de Gauss simple
#
# b) eliminación de Gauss con pivoteo parcial
#
# c) método de Gauss-Jordan sin pivoteo parcial.

# %%
# A)
m,r,x,d,y = [],[],[],0.0,0.0    
m=[[1.0,1.0,-1.0],[6.0,2.0,2.0],[-3.0,4.0,1.0]] 
r=[-3.0,2.0,1.0]
x=[0.0,0.0,0.0]

def haciaAdelante():
    for i in range(0,n):
        for j in range(i,n):
            if (i==j):
                d = m[i][j]
                for s in range (0,n):
                    m[i][s]=((m[i][s])/d)
                r[i]=((r[i])/d)
            else:
                d=m[j][i]
                for s in range (0,n):
                    m[j][s]=m[j][s]-(d*m[i][s])
                r[j]=r[j]-(d*r[i])
def haciaAtras():
    i=n-1
    j=n-1
    while (i>=0):
        y = r[i]
        while (j>=i):
            y=y-x[j]*m[i][j]
            j -= 1
        x[i]=y
        i -= 1
        j=n-1
    for i in range(0,n):
        k=i+1
        print ("El valor de la incognita X%d es %f"%(k,x[i]))
haciaAdelante()
haciaAtras()
# Out:
# El valor de la incognita X1 es -0.250000
# El valor de la incognita X2 es -0.500000
# El valor de la incognita X3 es 2.250000

# %%
#    b)

m,b,x,n,det,factor,tol,s,er = [],[],[],3,1.0,0.0,0.0,[],0.0
m=[[1.0,1.0,-1.0],[6.0,2.0,2.0],[-3.0,4.0,1.0]] 
b=[-3.0,2.0,1.0]
x=[0.0,0.0,0.0]
s=[0.0,0.0,0.0]
        
def eliminate(m,s,n,b,tol,er):
    for k in range(0,n):
        pivot(m,b,s,n,k)
        if (abs(m[k][k]/s[k])<tol):
            er=-1
        for i in range(k+1,n):
            factor = m[i][k]/m[k][k]
            for j in range (k+1,n):
                m[i][j]=m[i][j]-factor*m[k][j]
            b[i]=b[i]-factor*b[k]
    
    if (abs(m[k][k]/s[k])<tol):
        er=-1
        
def pivot(m,b,s,n,k):
    p,k=0,0
    p=k
    big = abs(m[k][k]/s[k])
    for i in range(k+1,n):
        dummy = abs(m[i][k]/s[i])
        if (dummy>big):
            big=dummy
            p=i
    if (p!=k):
        for j in range(k,n):
            dummy=m[p][j]
            m[p][j]=m[k][j]
            m[k][j]=dummy
        dummy=b[p]
        b[p]=b[k]
        b[k]=dummy
        dummy=s[p]
        s[p]=s[k]
        s[k]=dummy
    
def substitute(m,n,b,x):
    x[n-1]=b[n-1]/m[n-1][n-1]
    i=n-1
    while (i>=0):
        suma = 0
        for j in range(i+1,n):
            suma=suma+x[j]*m[i][j]
        x[i]=(b[i]-suma)/m[i][i]
        i -= 1
    for i in range(0,n):
        k=i+1
        print ("El valor de la incognita X%d es %f"%(k,x[i]))
    
def gauss(m,b,n,x,tol,er):
    for i in range(0,n):
        s[i]=abs(m[i][1])
        for j in range(1,n):
            if (abs(m[i][j])>s[i]):
                s[i]=abs(m[i][j])
    eliminate(m,s,n,b,tol,er)
    if (er!=-1):
        substitute(m,n,b,x)
gauss(m,b,n,x,tol,er)
# Out:
# El valor de la incognita X1 es -0.250000
# El valor de la incognita X2 es -0.500000
# El valor de la incognita X3 es 2.250000

# %%
v,cte,m = 3,0,[]
m=[[1.0,1,-1,-3],[6,2,2,2],[-3,4,1,1]]

def div(m,cte,v):
    temp=0.0
    temp=m[cte][cte]
    for y in range(0,v+1):
        m[cte][y]=m[cte][y]/temp
        
def Ceros(m,cte,v):
    for x in range(0,v):
        if (x!=cte):
            c = m[x][cte]
            for z in range(0,v+1):
                m[x][z]=((-1*c)*m[cte][z])+m[x][z]
                
for a in range(0,v):
    div(m,cte,v)
    Ceros(m,cte,v)
    cte += 1
for x in range(0,v):
    print ("La variable X%d es: %f"%(x+1,m[x][v]))
# Out:
# La variable X1 es: -0.250000
# La variable X2 es: -0.500000
# La variable X3 es: 2.250000
