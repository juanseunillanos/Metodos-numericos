# %%
#1y2----ingresar para el primero 0 y 0.8
#cuando aparesca el integral con regla de trapecio multiple ingresar 2, 0 , 0.4 y 0.8
a = float(input("Punto que iniciara la integracion: "))
b = float(input("Punto en el que termina la integracion: "))

def evaluar(x):
    f = 0.2 + 25*x - 200*x**2 + 675*x**3 - 900*x**4 + 400*x**5
    return f

def trap(h,f0,f1):
    trap = h*(f0+f1)/2
    return trap

print ("integral con regla de trapecio de un segmento : ")
print(trap(b-a,evaluar(a),evaluar(b)))
#----------------------------------------------------------------------------------------------------------------------------
print("integral con regla de trapecio multiples")
f,n,x = [],2,[]
n = int(input("Ingrese el numero de segmentos: "))

for k in range(n+1):
    x.append(float(input("Ingrese el punto X%d " %k)))
    
def evaluar(x):
    f.append(0.2+25*x-200*x**2+675*x**3-900*x**4+400*x**5)
    
for j in range(n+1):
    evaluar(x[j])

def trapmult(h,n,f):
    suma = f[0]
    for i in range(n-1):
        suma = suma + 2 * f[i+1]
    suma = suma + f[n]
    trapm = h * (suma/(2*n))
    return trapm
h = (x[n]-x[0])

print ("integral con regla de trapecio con multiples segmentos : ")
print(trapmult(h,n,f))

#----------------------------------------------------------------------------------------------------------------------------
# Out:
# Punto que iniciara la integracion: 0
# Punto en el que termina la integracion: 0.8
# integral con regla de trapecio de un segmento :
# 0.1728000000000225
# integral con regla de trapecio multiples
# Ingrese el numero de segmentos: 2
# Ingrese el punto X0 0
# Ingrese el punto X1 0.4
# Ingrese el punto X2 0.8
# integral con regla de trapecio con multiples segmentos :
# 1.0688000000000115

# %%
#3
a = 0
b = 0.8
f1,n,x1 = [],5,[0,0.16,0.32,0.48,0.64,0.80]

def evaluar1(x):
    f1.append(0.2+25*x-200*x**2+675*x**3-900*x**4+400*x**5)
        
def evaluar(x):
    f = 0.2+25*x-200*x**2+675*x**3-900*x**4+400*x**5
    return f
    
def simp13(h,f0,f1,f2):
    s = h*(f0+4*f1+f2)/6
    return s

f0 = evaluar(a)
f1 = evaluar((a+b)/2)
f2 = evaluar(b)

print ("Integracion con regla de Simpson 1/3 con un segmento: para el punto 3 y 4 ")
print(simp13(b-a,f0,f1,f2)) 
#----------------------------------------------------------------------------------------------------------------------------
#parte2
f,n,x = [],5,[0,0.16,0.32,0.48,0.64,0.80]

def evaluar(x):
    f.append(0.2+25*x-200*x**2+675*x**3-900*x**4+400*x**5)
    
for j in range(n+1):
    evaluar(x[j])
    
def simp13m(h,n,f):
    sum = f[0]
    i = 1
    while (i<=n-1):
        sum = sum + 4*f[i]       
        i = i+2
    j = 2
    while (j<=n-2):
        sum = sum + 2*f[j]  
        j = j+2
    sum = sum + f[n]
    simp13 = h*(sum/(3*n))
    return simp13
    
h = x[n]-x[0]

print("Integracion con regla de Simpson 1/3 con multiples segmentos punto 3 : ")
print(simp13m(h,n,f))
print("")
f,n,x = [],4,[0,0.2,0.4,0.6,0.8]
def evaluar(x):
    f.append(0.2+25*x-200*x**2+675*x**3-900*x**4+400*x**5)
    
for j in range(n+1):
    evaluar(x[j])
print("Integracion con regla de Simpson 1/3 con multiples segmentos  punto 4: ")
print(simp13m(h,n,f))
# Out:
# Integracion con regla de Simpson 1/3 con un segmento: para el punto 3 y 4
# 1.3674666666666744
# Integracion con regla de Simpson 1/3 con multiples segmentos punto 3 :
# 1.165361152000005
#
# Integracion con regla de Simpson 1/3 con multiples segmentos  punto 4:
# 1.6234666666666642

# %%
#5
a=0
b=0.8
def evaluar(x):
    f = 0.2+25*x-200*x**2+675*x**3-900*x**4+400*x**5
    return f
    
def simp38(h,f0,f1,f2,f3):
    simp13 = h*(f0+3*f1+3*f2+f3)/8
    return simp13

f0 = evaluar(a)
f1 = evaluar((a+b)/3)
f2 = evaluar(((a+b)/3+b)/2)
f3 = evaluar(b)

print ("Integracion con regla de Simpson 3/8 con un segmento: ")
print(simp38(b-a,f0,f1,f2,f3))
#---------------------------------------------------------------------------------------------------------------------------
# Out:
# Integracion con regla de Simpson 3/8 con un segmento:
# 1.519170370370378

# %%
#5 parte completa
n,f=5,[]
a=0
b=0.8


def evaluar(x):
    f.append(0.2+25*x-200*x**2+675*x**3-900*x**4+400*x**5)
aux = 0    
for j in range(n+1):
    evaluar(aux)
    aux = aux + 0.16
    
def trap(h,f0,f1):
    trap = h*(f0+f1)/2
    return trap

def simp38(h,f0,f1,f2,f3):
    simp13 = h*(f0+3*f1+3*f2+f3)/8
    return simp13

def simp13m(h,n,f):
    suma = f[0]
    i = 1
    while (i<=n-1):
        suma = suma + 4*f[i]       
        i = i+2
    j = 2
    while (j<=n-2):
        suma = suma + 2*f[j]  
        j = j+2
    suma = suma + f[n]
    simp13 = h*(suma/(3*n))
    return simp13

def simpInt(a,b,n,f):
    suma = 0.0
    h = (b-a)
    if (n==1):
        suma = trap(h,f[n-1],f[n])
    else:
        m=n
        if (n%2==0 and n>1):
            suma = suma + simp38(h,f[n-3],f[n-2],f[n-1],f[n])
            m = n-3
        if (m>1):
            suma = suma + simp13m(h,m,f)
    simpInt = suma
    return simpInt
print (simpInt(a,b,n,f))
# Out:
# 1.165361152000005

# %%
#7
x,h = 0.5,0.25

def fun(X):
    f = -0.1*X**4-0.15*X**3-0.5*X**2-0.25*X+1.2
    return f

xi_1 = fun(x-h)
xi_2 = fun(x-2*h)
xi = fun(x)
xi1 = fun(x+h)
xi2 = fun(x+2*h)

df1 = (-xi2+4*xi1-3*xi)/(2*h)
print ("Diferencia hacia adelante: ")
print(df1)
    
df2 = (3*xi-4*xi_1+xi_2)/(2*h)
print ("Diferencia hacia atras: ")
print(df2)
    
df3 = (-xi2+8*xi1-8*xi_1+xi_2)/(12*h)
print ("Diferencia centrada: ")
print(df3)
# Out:
# Diferencia hacia adelante:
# -0.8593750000000009
# Diferencia hacia atras:
# -0.8781250000000003
# Diferencia centrada:
# -0.9125000000000002

# %%
x = float(input(" valor en el cual quiere estimar la derivada: "))
h = float(input("tamaño de paso: "))

def fun(X):
    f = -0.1*X**4-0.15*X**3-0.5*X**2-0.25*X+1.2
    return f

xi = fun(x)
xi1 = fun(x+h)
xi2 = fun(x+2*h)
xi3 = fun(x+3*h)
xi4 = fun(x+4*h)
xi5 = fun(x+5*h)

def primeraDerivada():
    df1 = (xi1-xi)/h
    df2 = (-xi2+4*xi1-3*xi)/(2*h)
    print ("Primera derivada: ")
    print(df1)
    print ("Primera derivada con mas terminos: ")
    print(df2)
    
def segundaDerivada():
    d2f1 = (xi2-2*xi1+xi)/h**2
    d2f2 = (-xi3+4*xi2-5*xi1+2*xi)/h**2
    print ("Segunda derivada: ")
    print(d2f1)
    print ("Segunda derivada con mas terminos: ")
    print(d2f2)
    
def terceraDerivada():
    d3f1 = (xi3-3*xi2+3*xi1-xi)/h**3
    d3f2 = (-3*xi4+14*xi3-24*xi2+18*xi1-5*xi)/(2*h**3)
    print("Tercera derivada: ")
    print(d3f1)
    print ("Tercera derivada con mas terminos: ")
    print(d3f2)
    
def cuartaDerivada():
    d4f1 = (xi4-4*xi3+6*xi2-4*xi1+xi)/h**4
    d4f2 = (-2*xi5+11*xi4-24*xi3+26*xi2-14*xi1+3*xi)/h**4
    print ("Cuarta derivada: ")
    print(d4f1)
    print ("Cuarta derivada con mas terminos: ")
    print(d4f2)
    
    
primeraDerivada()
segundaDerivada()
terceraDerivada()
cuartaDerivada()
print("")
print("23.2")
x = float(input("Ingrese el valor en el cual quiere estimar la derivada: "))
h = float(input("Ingrese el tamaño de paso: "))

def fun(X):
    f = -0.1*X**4-0.15*X**3-0.5*X**2-0.25*X+1.2
    return f

xi = fun(x)
xi1 = fun(x-h)
xi2 = fun(x-2*h)
xi3 = fun(x-3*h)
xi4 = fun(x-4*h)
xi5 = fun(x-5*h)
primeraDerivada()
segundaDerivada()
terceraDerivada()
cuartaDerivada()
# Out:
#  valor en el cual quiere estimar la derivada: 0.5
# tamaño de paso: 0.25
# Primera derivada:
# -1.1546875
# Primera derivada con mas terminos:
# -0.8593750000000009
# Segunda derivada:
# -2.362499999999999
# Segunda derivada con mas terminos:
# -1.6124999999999972
# Tercera derivada:
# -3.000000000000007
# Tercera derivada con mas terminos:
# -2.0999999999999943
# Cuarta derivada:
# -2.4000000000000057
# Cuarta derivada con mas terminos:
# -2.39999999999975
#
# 23.2
# Ingrese el valor en el cual quiere estimar la derivada: 0.5
# Ingrese el tamaño de paso: 0.25
# Primera derivada:
# 0.7140625000000003
# Primera derivada con mas terminos:
# 0.8781249999999998
# Segunda derivada:
# -1.3125000000000018
# Segunda derivada con mas terminos:
# -1.6125000000000078
# Tercera derivada:
# 1.2000000000000384
# Tercera derivada con mas terminos:
# 2.1000000000001364
# Cuarta derivada:
# -2.400000000000176
# Cuarta derivada con mas terminos:
# -2.4000000000002046

# %%
print("")
print("23.3")
x = float(input("Ingrese el valor en el cual quiere estimar la derivada: "))
h = float(input("Ingrese el tamaño de paso: "))

def fun(X):
    f = -0.1*X**4-0.15*X**3-0.5*X**2-0.25*X+1.2
    return f

xi = fun(x)
xi1 = fun(x+h)
xi2 = fun(x+2*h)
xi_1 = fun(x-h)
xi_2 = fun(x-2*h)
xi_3 = fun(x-3*h)

def primeraDerivada():
    df1 = (xi1-xi_1)/(2*h)
    df2 = (-xi2+8*xi1-8*xi_1+xi_2)/(12*h)
    print ("Primera derivada: ")
    print(df1)
    print ("Primera derivada con mas terminos: ")
    print(df2)
def segundaDerivada():
    d2f1 = (xi1-2*xi+xi_1)/h**2
    d2f2 = (-xi2+16*xi1-30*xi+16*xi_1-xi_2)/(12*h**2)
    print ("Primera derivada: ")
    print(d2f1)
    print ("Primera derivada con mas terminos: ")
    print(d2f2)
def terceraDerivada():
    d3f1 = (xi2-2*xi1+2*xi_1-xi_2)/(2*h**3)
    d3f2 = (-xi3+8*xi2-13*xi1+13*xi_1-8*xi_2+xi_3)/(8*h**3)
    print ("Primera derivada: ")
    print(d3f1)
    print ("Primera derivada con mas terminos: ")
    print(d3f2)
def cuartaDerivada():
    d4f1 = (xi2-4*xi1+6*xi-4*xi_1+xi_2)/h**4
    d4f2 = (-xi3+12*xi2+39*xi1+56*xi-39*xi_1+12*xi_2+xi_3)/(6*h**4)
    print ("Primera derivada: ")
    print(d4f1)
    print ("Primera derivada con mas terminos: ")
    print(d4f2)
primeraDerivada()
segundaDerivada()
terceraDerivada()
cuartaDerivada()
# Out:
# 23.3
# Ingrese el valor en el cual quiere estimar la derivada: 0.5
# Ingrese el tamaño de paso: 0.25
# Primera derivada:
# -0.9343750000000002
# Primera derivada con mas terminos:
# -0.9125000000000002
# Primera derivada:
# -1.7624999999999993
# Primera derivada con mas terminos:
# -1.7499999999999962
# Primera derivada:
# -2.0999999999999943
# Primera derivada con mas terminos:
# -15.412499999999996
# Primera derivada:
# -2.3999999999999204
# Primera derivada con mas terminos:
# 2149.5333333333333
